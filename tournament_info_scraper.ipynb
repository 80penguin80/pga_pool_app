# %%
import pandas as pd

golf_tournaments = {
    "tournament_name": [
        "WM Phoenix Open",
        "The Genesis Invitational",
        "Mexico Open at Vidanta",
        "Cognizant Classic in The Palm Beaches",
        "Arnold Palmer Invitational presented by Mastercard",
        "THE PLAYERS Championship",
        "Valspar Championship",
        "Texas Children's Houston Open",
        "The Valero Texas Open",
        "Masters Tournament",
        "RBC Heritage",
        "Corales Puntacana Championship",
        "THE CJ CUP Byron Nelson",
        "Myrtle Beach Classic",
        "Wells Fargo Championship",
        "PGA Championship",
        "Charles Schwab Challenge",
        "RBC Canadian Open",
        "the Memorial Tournament presented by Workday",
        "U.S. Open",
        "Travelers Championship",
        "Rocket Mortgage Classic",
        "John Deere Classic",
        "Genesis Scottish Open",
        "Barracuda Championship",
        "The Open Championship",
        "3M Open",
        "Wyndham Championship",
        "FedEx St. Jude Championship",
        "BMW Championship",
        "TOUR Championship"
    ],
    "dates": [
        "Feb 8 - Feb 11", "Feb 15 - Feb 18", "Feb 22 - Feb 25", "Feb 29 - Mar 3", "Mar 7 - Mar 10", "Mar 14 - Mar 17", "Mar 21 - Mar 24", "Mar 28 - Mar 31", "Apr 4 - Apr 7", "Apr 11 - Apr 14", "Apr 18 - Apr 21", "Apr 18 - Apr 21", "May 2 - May 5", "May 9 - May 12", "May 9 - May 12", "May 16 - May 19", "May 23 - May 26", "May 30 - Jun 2", "Jun 6 - Jun 9", "Jun 13 - Jun 16", "Jun 20 - Jun 23", "Jun 27 - Jun 30", "Jul 4 - Jul 7", "Jul 11 - Jul 14", "Jul 18 - Jul 21", "Jul 18 - Jul 21", "Jul 25 - Jul 28", "Aug 8 - Aug 11", "Aug 15 - Aug 18", "Aug 22 - Aug 25", "Aug 29 - Sep 1"
    ],
    "purse": [
        "$8,800,000.00", "$20,000,000.00", "$8,100,000.00", "$9,000,000.00", "$20,000,000.00", "$25,000,000.00", "$8,400,000.00", "$9,100,000.00", "$9,200,000.00", "$0.00", "$20,000,000.00", "$4,000,000.00", "$9,500,000.00", "$4,000,000.00", "$20,000,000.00", "$0.00", "$9,100,000.00", "$9,400,000.00", "$20,000,000.00", "$0.00", "$20,000,000.00", "$9,200,000.00", "$7,800,000.00", "$9,000,000.00", "$4,000,000.00", "$0.00", "$8,300,000.00", "$7,900,000.00", "$20,000,000.00", "$20,000,000.00", "$0.00"
    ]
}

pd.DataFrame(golf_tournaments)
# Out:
#                                       tournament_name            dates  \
# 0                                     WM Phoenix Open   Feb 8 - Feb 11
# 1                            The Genesis Invitational  Feb 15 - Feb 18
# 2                              Mexico Open at Vidanta  Feb 22 - Feb 25
# 3               Cognizant Classic in The Palm Beaches   Feb 29 - Mar 3
# 4   Arnold Palmer Invitational presented by Master...   Mar 7 - Mar 10
# 5                            THE PLAYERS Championship  Mar 14 - Mar 17
# 6                                Valspar Championship  Mar 21 - Mar 24
# 7                       Texas Children's Houston Open  Mar 28 - Mar 31
# 8                               The Valero Texas Open    Apr 4 - Apr 7
# 9                                  Masters Tournament  Apr 11 - Apr 14
# 10                                       RBC Heritage  Apr 18 - Apr 21
# 11                     Corales Puntacana Championship  Apr 18 - Apr 21
# ...

# %%
cleaned_purse = []

for a in golf_tournaments['purse']:
    new = (((a.replace(',','')).split('$')[1]).split('.')[0])
    cleaned_purse.append(int(new))

# %%
golf_tournaments['purse'] = cleaned_purse

# %%
pd.DataFrame(golf_tournaments).to_csv('/Users/zack burnside/desktop/tournament_info.csv')
